# %% [markdown]
# Name: Alcontin, Angelo P.
#
# Student Number: 2022101212
#
# Course/Section: DS100-1/B31
#
# M3 Programming Exercise

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn import metrics

sheet_name = "pH "
data = pd.read_excel('https://github.com/NEXangelo/M3-PROGRAMMING-EXERCIE/raw/main/Applied-Data-Science-3Q2324-M3-Dataset.xlsx', sheet_name=sheet_name)

data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y')


data['Day'] = data['Date'].dt.day
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

start_date = data['Date'].min()
data['Total_Days'] = (data['Date'] - start_date).dt.days

# %%
plt.figure(figsize=(10, 5))

# Plot for Station I 
plt.scatter(X_test_station_1, y_test_station_1, color='red', label='True Values (Station I)')
plt.plot(X_test_station_1, target_station_1, color='blue', linewidth=2, label='Linear Regression Line (Station I)')

# Plot for Station II
plt.scatter(X_test_station_2, y_test_station_2, color='green', label='True Values (Station II)')
plt.plot(X_test_station_1, target_station_2, color='orange', linewidth=2, label='Linear Regression Line (Station II)')  # Using X_test_station_1 for consistency

plt.title('pH Predictions for Stations I and II')
plt.xlabel('Total Days')
plt.ylabel('pH Predictions')
plt.xlim(0, max(X_test_station_1.max(), X_test_station_2.max()))
plt.legend()
plt.text(0.1, 0.9, f'Station I Coeff: {linreg_station_1.coef_[0][0]:.2f}, Intercept: {linreg_station_1.intercept_[0]:.2f}\nStation II Coeff: {linreg_station_2.coef_[0][0]:.2f}, Intercept: {linreg_station_2.intercept_[0]:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='top')

plt.tight_layout()
plt.show()

# %%
print('Station IV (Central Bay):')
print('R-squared Score (test):', r2_station_1)
print('R-squared Score (train):', model_station_1.score(X_train_station_1, y_train_station_1))
print('Mean Squared Error:', metrics.mean_squared_error(y_test_station_1, target_station_1))

print('\nStation V (Northern West Bay):')
print('R-squared Score (test):', r2_station_2)
print('R-squared Score (train):', model_station_2.score(X_train_station_2, y_train_station_2))
print('Mean Squared Error:', metrics.mean_squared_error(y_test_station_2, target_station_2))


print('\nEquation for Station IV (Central Bay): Ammonia =', linreg_station_1.intercept_[0], '+', linreg_station_1.coef_[0][0], '* Total_Days')
print('Equation for Station V (Northern West Bay): Ammonia =', linreg_station_2.intercept_[0],'+', linreg_station_2.coef_[0][0], '* Total_Days')
# Out:
# Station IV (Central Bay):
# R-squared Score (test): -370.15714924963874
# R-squared Score (train): -1.0576907084450613
# Mean Squared Error: 66.7968710356617
#
# Station V (Northern West Bay):
# R-squared Score (test): -419.4794399148998
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 8
#       6 print('\nStation V (Northern West Bay):')
#       7 print('R-squared Score (test):', r2_station_2)
# ----> 8 print('R-squared Score (train):', model_station_2.score(X_train_station_2, y_train_station_2))
#       9 print('Mean Squared Error:', metrics.mean_squared_error(y_test_station_2, target_station_2))
#      12 print('\nEquation for Station IV (Central Bay): Ammonia =', linreg_station_1.intercept_[0], '+', linreg_station_1.coef_[0][0], '* Total_Days')
#
# ...
